# %% [markdown]
# * Atividade 1
# ===========

# %% [markdown]
# 1. Faça um Programa que peça o raio de um círculo, calcule e mostre sua área.

# %%
raio = float(input("Digite o raio do circulo: "))
area = 3.14 * raio * raio
print("A área do circulo é: ", area)
# Out:
# Digite o raio do circulo: 20
# A área do circulo é:  1256.0

# %% [markdown]
# 2. Faça um Programa que calcule a área de um quadrado, em seguida mostre o dobro
# desta área para o usuário.

# %%
base = float(input("Qual o tamanho da base do quadrado: "))
height = base
area = base * height
double = area * 2
print("Á area do seu quadrado é: {} e o dobro dela é: {}".format(area, double))
# Out:
# Qual o tamanho da base do quadrado: 20
# Á area do seu quadrado é: 400.0 e o dobro dela é: 800.0

# %% [markdown]
# 3. Faça um Programa que pergunte quanto você ganha por hora e o número de horas
# trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
hours = float(input("Qual o valor em R$ você ganhar por hora? "))
numbers_of_hours = float(input("Quantas horas você trabalhar por mês? "))
print("O valor do seu salário é: {}".format(hours * numbers_of_hours))
# Out:
# Qual o valor em R$ você ganhar por hora? 20
# Quantas horas você trabalhar por mês? 50
# O valor do seu salário é: 1000.0

# %% [markdown]
# 4. Faça um Programa que peça a temperatura em graus Farenheit, transforme e
# mostre a temperatura em graus Celsius. C = (5 * (F-32) / 9).

# %%
print("A temperatura em Celsius é: {}".format((5 * (float(input("Qual temperatura em Farenheit? ")) - 32) / 9)))
# Out:
# Qual temperatura em Farenheit? 50
# A temperatura em Celsius é: 10.0

# %% [markdown]
# 5. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre
# em graus Farenheit.

# %%
print("A temperatura em Farenheit é: {}".format(((float(input("Qual temperatura em Celsius? "))) * 9/5) + 32))
# Out:
# Qual temperatura em Celsius? 10
# A temperatura em Farenheit é: 50.0

# %% [markdown]
# 6. Faça um Programa que peça 2 números inteiros e um número real. Calcule e
# mostre:
#   - o produto do dobro do primeiro com metade do segundo .
#   - a soma do triplo do primeiro com o terceiro.
#   - o terceiro elevado ao cubo.

# %%
numbers_str = input("Digite 3 números separados por espaço e sem pontuação: ")
numbers_list = [float(n) for n in numbers_str.split()]
one = numbers_list[0]
two = numbers_list[1]
three = numbers_list[2]

print("O produto do dobro do primeiro com metade do segundo é: {}".format(one * 2 + two / 2))
print("A soma do triplo do primeiro com o terceiro é: {}".format(one * 3 + three))
print("O terceiro elevado ao cubo é: {}".format(three ** 3))
# Out:
# Digite 3 números separados por espaço e sem pontuação:  1 2 3
# O produto do dobro do primeiro com metade do segundo é: 3.0
# A soma do triplo do primeiro com o terceiro é: 6.0
# O terceiro elevado ao cubo é: 27.0

# %% [markdown]
# 7. João Papo-de-Pescador, homem de bem, comprou um microcomputador para
# controlar o rendimento diário de seu trabalho. Toda vez que ele traz um peso de
# peixes maior que o estabelecido pelo regulamento de pesca do estado de São Paulo
# (50 quilos) deve pagar uma multa de R$ 4,00 por quilo excedente. João precisa que
# você faça um programa que leia a variável peso (peso de peixes) e verifique se há excesso. Se houver, gravar na variável excesso e na variável multa o valor da multa
# que João deverá pagar. Caso contrário mostrar tais variáveis com o conteúdo ZERO.

# %%
peso = float(input("Digite o peso do peixe: "))

if (peso > 50):
  print("O valor total da multa será de: R$ {}".format((peso - 50) * 4))
else:
  print("Você não pagará multa! =)")
# Out:
# Digite o peso do peixe: 50
# Você não pagará multa! =)

# %% [markdown]
# 8. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês, sabendo-se que são descontados 11% para o Imposto de Renda, 8% para o INSS e 5% para o sindicato, faça um programa que nos dê:
#   - salário bruto.
#   - quanto pagou ao INSS.
#   - quanto pagou ao sindicato.
#   - o salário líquido.
#   - calcule os descontos
#   - salário líquido

# %%
hours = float(input("Qual o valor em R$ você ganhar por hora? "))
numbers_of_hours = float(input("Quantas horas você trabalhar por mês? "))
bruto = hours * numbers_of_hours
ir = bruto * 11 / 100
inss = bruto * 8 / 100
sindicato = bruto * 5 / 100
liquido = bruto - ir - inss - sindicato
print("\nO valor do seu salário bruto esse mês é: {}".format(bruto))
print("O valor do seu salário liquido esse mês é: {}".format(liquido))
print("\n== IMPOSTOS ==\n* IR: {}\n* INSS: {}\n* Sindicado: {}".format(ir, inss, sindicato))
# Out:
# Qual o valor em R$ você ganhar por hora? 20
# Quantas horas você trabalhar por mês? 160
#
# O valor do seu salário bruto esse mês é: 3200.0
# O valor do seu salário liquido esse mês é: 2432.0
#
# == IMPOSTOS ==
# * IR: 352.0
# * INSS: 256.0
# * Sindicado: 160.0

# %% [markdown]
# 9. Faça um programa que leia 2 strings e informe o conteúdo delas seguido do seu
# comprimento. Informe também se as duas strings possuem o mesmo comprimento e
# são iguais ou diferentes no conteúdo.

# %%
one = input("Digite uma sequência de caracteres: ")
two = input("Digite outra sequência de caracteres: ")
print("Tamanho de '{}' é: {} caracteres".format(one, len(one)))
print("Tamanho de '{}' é: {} caracteres".format(two, len(two)))
if (len(one) == len(two)):
  print("As duas strings são de tamanhos iguais!")
else:
  print("As duas strings são de tamanhos diferentes!")

if (one == two):
  print("As duas strings tem o mesmo conteúdo!")
else:
  print("As duas strings não tem o mesmo conteúdo")
# Out:
# Digite uma sequência de caracteres: Guga
# Digite outra sequência de caracteres: Guga
# Tamanho de 'Guga' é: 4 caracteres
# Tamanho de 'Guga' é: 4 caracteres
# As duas strings são de tamanhos iguais!
# As duas strings tem o mesmo conteúdo!

# %% [markdown]
# 10. Faça um programa que permita ao usuário digitar o seu nome e em seguida mostre o nome do usuário de trás para frente utilizando somente letras maiúsculas. Dica: lembre−se que ao informar o nome o usuário pode digitar letras maiúsculas ou minúsculas. Observação: não use loops.

# %%
name = input("Qual seu nome? ")
print("Seu nome ao contrário e com letras maiúsculas é: {}".format(name[::-1].upper()))
# Out:
# Qual seu nome? Guga
# Seu nome ao contrário e com letras maiúsculas é: AGUG

# %% [markdown]
# 11. Faça um programa que solicite a data de nascimento (dd/mm/aaaa) do usuário e imprima a data com o nome do mês por extenso.

# %%
date = input("Digite a sua data de nascimento: ")
date = [int(x) for x in date.split("/")]
months = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembto', 'Outubro', 'Novembro', 'Dezembro']
print("Você nasceu em {} de {} de {}!".format(date[0], months[date[1]-1], date[2]))
# Out:
# Digite a sua data de nascimento: 20/05/1999
# Você nasceu em 20 de Maio de 1999!

# %% [markdown]
# 12. Leet é uma forma de se escrever o alfabeto latino usando outros símbolos em
# lugar das letras, como números por exemplo. A própria palavra leet admite muitas
# variações, como l33t ou 1337. O uso do leet reflete uma subcultura relacionada ao
# mundo dos jogos de computador e internet, sendo muito usada para confundir os
# iniciantes e afirmar-se como parte de um grupo. Pesquise sobre as principais formas
# de traduzir as letras. Depois, faça um programa que peça uma texto e transforme-o
# para a grafia leet speak.

# %%
import re

text = input("Digite uma frase: ")
clone = text
text = re.sub("A|a", "4", text)
text = re.sub("T|t", "7", text)
text = re.sub("L|l", "1", text)
text = re.sub("E|e", "3", text)
text = re.sub("S|s", "5", text)
text = re.sub("O|o", "0", text)

print("Sua frase '{}' mudou para: {}".format(clone, text))
# Out:
# Digite uma fraze: Guga lindo
# Sua frase 'Guga lindo' mudou para: Gug4 1ind0
